# %% [markdown]
# # NLP Lab Tasks
#
# **Name:** Zawar Haider
# **Registration Number:** SP24-BDS-038

# %% [markdown]
# ## Task 1 — Strings and Basic Text Operations

# %%
sentence = "Artificial Intelligence is transforming Natural Language Processing"
print(sentence)
print(f"Data Type: {type(sentence)}")
print(f"Total No of Char: {len(sentence)}")
# Out:
# Artificial Intelligence is transforming Natural Language Processing
# Data Type: <class 'str'>
# Total No of Char: 67

# %%
print(f"First char: {sentence[0]}, Last Char: {sentence[-1]}")
print(f"Slice Range : {sentence[48:56]}")
# Out:
# First char: A, Last Char: g
# Slice Range : Language

# %%
print(f"Checking if intelligience exists: {"True", sentence.index("Intelligence") if "Intelligence" in sentence else "False"}")

paragraph = """Natural Language Processing allows computers to understand human language.
Text classification is an important application of NLP.
Sentiment analysis can identify emotions expressed in text."""

sentences = paragraph.split("\n")

for i, sentence in enumerate(sentences):
    print(f"Sentence NO#{i+1}: {sentence}")
# Out:
# Checking if intelligience exists: ('True', 11)
# Sentence NO#1: Natural Language Processing allows computers to understand human language.
# Sentence NO#2: Text classification is an important application of NLP.
# Sentence NO#3: Sentiment analysis can identify emotions expressed in text.

# %% [markdown]
# ## Task 2 — Lists and Token Operations

# %%
tokens = ["deep", "learning", "helps", "machines", "understand", "text"]
print(tokens)
print(f"Length: {len(tokens)}")
print(f"Element at index 2: {tokens[2]}\nLast Element: {tokens[-1]}")
# Out:
# ['deep', 'learning', 'helps', 'machines', 'understand', 'text']
# Length: 6
# Element at index 2: helps
# Last Element: text

# %%
tokens.append("efficiently")
print(tokens)

tokens.insert(3, "computers")
print(tokens)

tokens.remove("helps")
print(tokens)
# Out:
# ['deep', 'learning', 'helps', 'machines', 'understand', 'text', 'efficiently']
# ['deep', 'learning', 'helps', 'computers', 'machines', 'understand', 'text', 'efficiently']
# ['deep', 'learning', 'computers', 'machines', 'understand', 'text', 'efficiently']

# %%
tokens_A = ["NLP", "uses", "Python"] 
tokens_B = ["for", "text", "analysis"]
full_tokens = tokens_A + tokens_B
print(full_tokens)
print(full_tokens[-3:])
# Out:
# ['NLP', 'uses', 'Python', 'for', 'text', 'analysis']
# ['for', 'text', 'analysis']

# %%
sorted_tokens = sorted(full_tokens)
length_sorted = sorted(full_tokens, key=len)

print("Alphabetically sorted:", sorted_tokens)
print("Length sorted:", length_sorted)
# Out:
# Alphabetically sorted: ['NLP', 'Python', 'analysis', 'for', 'text', 'uses']
# Length sorted: ['NLP', 'for', 'uses', 'text', 'Python', 'analysis']

# %% [markdown]
# ## Task 3 — Dictionaries

# %%
word_freq = {"machine": 4, "learning": 7, "data": 5, "model": 3, "text": 6}
print(word_freq)
print(word_freq['learning'])
word_freq['data'] = 9
print(word_freq)
# Out:
# {'machine': 4, 'learning': 7, 'data': 5, 'model': 3, 'text': 6}
# 7
# {'machine': 4, 'learning': 7, 'data': 9, 'model': 3, 'text': 6}

# %%
word_freq['neutral'] = 8
word_freq['network'] = 5
print(word_freq)

word_freq.pop('model')
print(word_freq)

print("Found" if "text" in word_freq else "Not Found")
# Out:
# {'machine': 4, 'learning': 7, 'data': 9, 'model': 3, 'text': 6, 'neutral': 8, 'network': 5}
# {'machine': 4, 'learning': 7, 'data': 9, 'text': 6, 'neutral': 8, 'network': 5}
# Found

# %%
vocab = {"nlp": 0, "python": 1, "token": 2, "vector": 3, "corpus": 4}
reverse = {}
for key, value in vocab.items():
    temp = key
    key = value
    value = temp

    reverse[key] = value
print(vocab)
print(reverse)
# Out:
# {'nlp': 0, 'python': 1, 'token': 2, 'vector': 3, 'corpus': 4}
# {0: 'nlp', 1: 'python', 2: 'token', 3: 'vector', 4: 'corpus'}

# %%
for key, value in word_freq.items():
    print(f"Word: {key} -> Frequency: {value}")
    
print(f"No of Unique word stored in Dict: {len(word_freq)}")
# Out:
# Word: machine -> Frequency: 4
# Word: learning -> Frequency: 7
# Word: data -> Frequency: 9
# Word: text -> Frequency: 6
# Word: neutral -> Frequency: 8
# Word: network -> Frequency: 5
# No of Unique word stored in Dict: 6

# %% [markdown]
# ## Task 4 — Sets

# %%
raw = ["nlp", "ai", "nlp", "deep", "learning", "ai", "nlp", "python"]
vocab = set()
for token in raw: 
    vocab.add(token)
# Set Only Stores Unique Values
print("Raw: ", raw)
print("Vocab", vocab)
# Out:
# Raw:  ['nlp', 'ai', 'nlp', 'deep', 'learning', 'ai', 'nlp', 'python']
# Vocab {'python', 'ai', 'nlp', 'learning', 'deep'}

# %%
set_A = {"machine", "learning", "data", "model"}
set_B = {"deep", "learning", "neural", "data"}

print(f"Union: {set.union(set_A, set_B)}")
print(f"Intersection: {set.intersection(set_A, set_B)}")
print(f"Difference: {set.difference(set_A, set_B)}")
print(f"Difference: {(set_A - set_B)}")
# Out:
# Union: {'data', 'model', 'machine', 'learning', 'deep', 'neural'}
# Intersection: {'data', 'learning'}
# Difference: {'model', 'machine'}
# Difference: {'model', 'machine'}

# %%
stopwords = {"is", "the", "a", "in", "of", "and", "to"}
tokens = ["nlp", "is", "a", "field", "of", "ai", "and", "the", "future"]
tokens = list(set.difference(set(tokens), stopwords))
print(tokens)
# Out:
# ['nlp', 'field', 'future', 'ai']

# %%
# words "transformer" and "bert" 
vocab.add("transformer")
vocab.add("bert")

vocab.discard("python")
print(vocab)

print("AI Present" if 'ai' in vocab else "Not Present")
# Out:
# {'ai', 'nlp', 'learning', 'deep', 'bert', 'transformer'}
# AI Present

# %% [markdown]
# ## Task 5 — Tuples

# %%
pos_tags = [("language", "NOUN"), ("processes", "VERB"),
             ("human", "ADJ"), ("text", "NOUN"), ("quickly", "ADV")]
print(pos_tags)
print(f"Word: {pos_tags[1][0]} Tag: {pos_tags[1][1]}")
# Out:
# [('language', 'NOUN'), ('processes', 'VERB'), ('human', 'ADJ'), ('text', 'NOUN'), ('quickly', 'ADV')]
# Word: processes Tag: VERB

# %%
word = pos_tags[0][0]
tag = pos_tags[0][1]
print(f"Word: {word}\nTag: {tag}")

try:
    pos_tags[0][1] = "VERB"
except Exception as e:
    print(e)
# Out:
# Word: language
# Tag: NOUN
# 'tuple' object does not support item assignment

# %%
def extract_nouns(pos_list):
    new_list = []
    for item in pos_list:
        if item[1] == "NOUN":
            new_list.append(item[0])
    return new_list

print(extract_nouns(pos_tags))
# Out:
# ['language', 'text']

# %%
pipeline_steps = ("load_data", "clean_text", "tokenize", "remove_stopwords", "vectorize")
print(pipeline_steps)
print(f"Pos of Tokenize: {pipeline_steps.index("tokenize")}\nTotal No of Steps: {len(pipeline_steps)}")
try:
    pipeline_steps[0] = None
except Exception as e:
    print(e)
# Out:
# ('load_data', 'clean_text', 'tokenize', 'remove_stopwords', 'vectorize')
# Pos of Tokenize: 2
# Total No of Steps: 5
# 'tuple' object does not support item assignment

# %% [markdown]
# ## Task 6 — String Methods

# %%
text = "   MACHINE Learning is AMAZING!!!   "

text = text.strip()
print("After strip():", text)

text = text.lower()
print("After lower():", text)

text = text.replace("!", "")
print("After replace():", text)
# Out:
# After strip(): MACHINE Learning is AMAZING!!!
# After lower(): machine learning is amazing!!!
# After replace(): machine learning is amazing

# %%
words = text.split()
print("Words:", words)

uppercase_words = [word.upper() for word in words]
print("Uppercase words:", uppercase_words)

result = " | ".join(uppercase_words)
print("Joined string:", result)
# Out:
# Words: ['machine', 'learning', 'is', 'amazing']
# Uppercase words: ['MACHINE', 'LEARNING', 'IS', 'AMAZING']
# Joined string: MACHINE | LEARNING | IS | AMAZING

# %%
sentence = "I love Java and Java is popular"

sentence = sentence.replace("Java", "Python")
print("Updated sentence:", sentence)

position = sentence.find("Python")
print("Position of first Python:", position)
# Out:
# Updated sentence: I love Python and Python is popular
# Position of first Python: 7

# %%
def normalize(text):
    text = text.strip()
    text = text.lower()
    text = text.replace(",", "")
    text = text.replace(".", "")
    return text


text1 = "   Hello, WORLD.   "
text2 = "  Python, is AMAZING.  "

print(normalize(text1))
print(normalize(text2))
# Out:
# hello world
# python is amazing

# %% [markdown]
# ## Task 7 — String Validation

# %%
text = "NLP is the future of AI research"

if text.startswith("NLP"):
    print("The text starts with NLP.")
else:
    print("The text does not start with NLP.")

if text.endswith("research"):
    print("The text ends with research.")
else:
    print("The text does not end with research.")

position = text.find("future")
print("Position of future:", position)
# Out:
# The text starts with NLP.
# The text ends with research.
# Position of future: 11

# %%
tokens = ["hello", "123", "world", "456abc", "python", "789", "NLP3"]

for token in tokens:
    if token.isalpha():
        print(token, "-> Alphabetic")
    elif token.isdigit():
        print(token, "-> Numeric")
    else:
        print(token, "-> Mixed")
# Out:
# hello -> Alphabetic
# 123 -> Numeric
# world -> Alphabetic
# 456abc -> Mixed
# python -> Alphabetic
# 789 -> Numeric
# NLP3 -> Mixed

# %%
words = ["running", "jumped", "NLP", "ai2025", "data", "42"]

pure_words = []
pure_numbers = []
mixed_tokens = []

for word in words:
    if word.isalpha():
        pure_words.append(word)
    elif word.isdigit():
        pure_numbers.append(word)
    else:
        mixed_tokens.append(word)

print("Pure words:", pure_words)
print("Pure numbers:", pure_numbers)
print("Mixed tokens:", mixed_tokens)
# Out:
# Pure words: ['running', 'jumped', 'NLP', 'data']
# Pure numbers: ['42']
# Mixed tokens: ['ai2025']

# %%
def validate_token(token):
    if token.isalpha():
        return "WORD"
    elif token.isdigit():
        return "NUMBER"
    else:
        return "MIXED"


tokens = ["chat", "99", "gpt4", "bert", "2024", "nlp!"]

for token in tokens:
    print(token, "->", validate_token(token))
# Out:
# chat -> WORD
# 99 -> NUMBER
# gpt4 -> MIXED
# bert -> WORD
# 2024 -> NUMBER
# nlp! -> MIXED

# %% [markdown]
# ## Task 8 — Functions and NLP Processing

# %%
def clean(text):
    text = text.strip()
    text = text.lower()
    return text


clean_lambda = lambda text: text.strip().lower()


text = "   HELLO Natural Language Processing   "

print("Using function:", clean(text))
print("Using lambda:", clean_lambda(text))
# Out:
# Using function: hello natural language processing
# Using lambda: hello natural language processing

# %%
def tokenize(text):
    return text.split()


def remove_short(tokens, n):
    return [token for token in tokens if len(token) > n]


sentence = "I love working with NLP tools in Python daily"

tokens = tokenize(sentence)
result = remove_short(tokens, 3)

print("Result:", result)
# Out:
# Result: ['love', 'working', 'with', 'tools', 'Python', 'daily']

# %%
def word_lengths(tokens):
    result = {}

    for word in tokens:
        result[word] = len(word)

    return result


tokens = ["language", "model", "ai", "processing", "deep"]

print(word_lengths(tokens))
# Out:
# {'language': 8, 'model': 5, 'ai': 2, 'processing': 10, 'deep': 4}

# %%
def nlp_pipeline(text, min_len):
    text = clean(text)
    tokens = tokenize(text)
    tokens = remove_short(tokens, min_len)
    return word_lengths(tokens)


sentence1 = "   Python is a powerful programming language   "
sentence2 = "   NLP is useful for text processing   "

print("Sentence 1:", nlp_pipeline(sentence1, 3))
print("Sentence 2:", nlp_pipeline(sentence2, 3))
# Out:
# Sentence 1: {'python': 6, 'powerful': 8, 'programming': 11, 'language': 8}
# Sentence 2: {'useful': 6, 'text': 4, 'processing': 10}

# %% [markdown]
# ## Task 9 — Map, Filter and Counter

# %%
words = ["Python", "NLP", "is", "a", "powerful", "tool", "for", "text"]

lowercase_words = list(map(lambda word: word.lower(), words))
print("Lowercase:", lowercase_words)

word_lengths = list(map(lambda word: len(word), words))
print("Lengths:", word_lengths)
# Out:
# Lowercase: ['python', 'nlp', 'is', 'a', 'powerful', 'tool', 'for', 'text']
# Lengths: [6, 3, 2, 1, 8, 4, 3, 4]

# %%
words_long = list(filter(lambda word: len(word) > 3, words))

words_with_t = list(filter(lambda word: "t" in word.lower(), words))

print("Words longer than 3 characters:", words_long)
print("Words containing t:", words_with_t)
# Out:
# Words longer than 3 characters: ['Python', 'powerful', 'tool', 'text']
# Words containing t: ['Python', 'tool', 'text']

# %%
alphabetical = sorted(words)
print("Alphabetical:", alphabetical)

length_ascending = sorted(words, key=len)
print("Length ascending:", length_ascending)

length_descending = sorted(words, key=len, reverse=True)
print("Length descending:", length_descending)
# Out:
# Alphabetical: ['NLP', 'Python', 'a', 'for', 'is', 'powerful', 'text', 'tool']
# Length ascending: ['a', 'is', 'NLP', 'for', 'tool', 'text', 'Python', 'powerful']
# Length descending: ['powerful', 'Python', 'tool', 'text', 'NLP', 'for', 'is', 'a']

# %%
from collections import Counter

sentence = "nlp nlp python ai nlp python text ai nlp python text"

words = sentence.split()

freq = Counter(words)

print("Full Counter:", freq)

print("3 most common:", freq.most_common(3))

print("Frequency of python:", freq["python"])

print("Total number of words:", len(words))

print("Unique vocabulary:", len(freq))
# Out:
# Full Counter: Counter({'nlp': 4, 'python': 3, 'ai': 2, 'text': 2})
# 3 most common: [('nlp', 4), ('python', 3), ('ai', 2)]
# Frequency of python: 3
# Total number of words: 11
# Unique vocabulary: 4
